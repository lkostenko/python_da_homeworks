# %% [markdown]
# <a href="https://colab.research.google.com/github/lkostenko/python_da_homeworks/blob/main/Kostenko_HW6_%D0%A4%D1%83%D0%BD%D0%BA%D1%86%D1%96%D1%97.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **1. Функція без параметрів**
#
# Створіть функцію `show_menu()`, яка приймає перелік страв, наприклад ['Піца', 'Паста', 'Салат'] і виводить меню ресторану в наступному вигляді:
# ```
# === МЕНЮ ===
# 1. Піца
# 2. Паста
# 3. Салат
# =============
# ```
#
# Викличте цю функцію на списку ["Суп грибний", "Котлета по-київськи", "Лимонад"].

# %%
def show_menu():
  menu = ["Суп грибний", "Котлета по-київськи", "Лимонад"]
  print(f'=== МЕНЮ ===')
  for i, dish in enumerate (menu,1):
    print(f'{i}. {dish}')
  print(f'=============')

# %%
show_menu()
# Out:
# === МЕНЮ ===
# 1. Суп грибний
# 2. Котлета по-київськи
# 3. Лимонад
# =============

# %% [markdown]
# ---
#
# **2. Функція з параметром**
#
# Створіть функцію `print_square(n)`, яка виводить квадрат числа.
#
# Наприклад: `print_square(5)` → "Квадрат числа 5 = 25"
#
# Викличте її з різними числами.

# %%
def print_square(n):
  sq = n**2
  print(f'Квадрат числа {n} = {sq}')

# %%
print_square(5)
# Out:
# Квадрат числа 5 = 25

# %%
import random

def print_square(n):
    sq = n**2
    print(f'Квадрат числа {n} = {sq}')

my_random_list = [random.randint(1, 100) for _ in range(7)]

for number in my_random_list:
    print_square(number)
# Out:
# Квадрат числа 47 = 2209
# Квадрат числа 40 = 1600
# Квадрат числа 17 = 289
# Квадрат числа 98 = 9604
# Квадрат числа 69 = 4761
# Квадрат числа 2 = 4
# Квадрат числа 54 = 2916

# %% [markdown]
# ---
#
# **3. Функція з поверненням значення**
#
# Створіть функцію `multiply(a, b)`, яка повертає добуток двох чисел.
#
# Викличте функцію на власноруч заданих значеннях та виведіть результат.

# %%
def multiply(a, b):
  print(a*b)

# %%
multiply(2,5)
# Out:
# 10

# %% [markdown]
# ---
#
# **4. Функція пошуку максимумального значення**
#
# Створіть функцію `find_max(numbers)`, яка:
# - Приймає список чисел
# - Повертає найбільше число в списку
#
# Протестуйте на списку `[15, 42, 8, 23, 56, 19]`.

# %%
def find_max(numbers):
  print(max(numbers))

# %%
numbers = [15, 42, 8, 23, 56, 19]
find_max(numbers)
# Out:
# 56

# %% [markdown]
# ---
#
# **5. Функція з умовами**
#
# Створіть функцію `check_grade(grade)`, яка:
# - Приймає оцінку (число)
# - Повертає "Здав" якщо grade >= 60
# - Повертає "Не здав" якщо grade < 60
#
# Протестуйте на різних оцінках.

# %%
def check_grade(grade):
  return "Здав" if grade >= 60 else "Не здав"

# %%
check_grade(65)
# Out:
# 'Здав'

# %%
my_random_list = [random.randint(1, 100) for _ in range(10)]

for number in my_random_list:
    print(number,'-' , check_grade(number))
# Out:
# 97 - Здав
# 64 - Здав
# 38 - Не здав
# 86 - Здав
# 12 - Не здав
# 34 - Не здав
# 60 - Здав
# 58 - Не здав
# 6 - Не здав
# 77 - Здав
